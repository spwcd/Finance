# %% [markdown]
# # Get Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Quandl

# %%
import quandl

# %%
AAPL = quandl.get('WIKI/AAPL')
AAPL.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
AAPL.plot(figsize=(12,8))
plt.xlabel('Date')
plt.ylabel('Prices')

# %%
AAPL['Adj. Close'].plot(figsize=(12,8))
plt.xlabel('Date')
plt.ylabel('Prices')

# %%
 AAPL = quandl.get('WIKI/AAPL', start_date='2015-01-01', end_date='2018-02-28')
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# <ipython-input-6-173e766c410d> in <module>()
# ----> 1 AAPL = quandl.get('WIKI/AAPL', start_date='2015-01-01', end_date='2018-02-28')
#
# /usr/local/lib/python3.5/dist-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /usr/local/lib/python3.5/dist-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
# ...

# %%
AAPL['Adj. Close'].plot(figsize=(12,8))
plt.xlabel('Date')
plt.ylabel('Prices')

# %% [markdown]
# # Siamchart

# %% [markdown]
# https://www.siamchart.com

# %%
import os 
cwd = os.getcwd()
print(cwd)
# Out:
# /home/poon/PycharmProjects/MyCourse/IPT

# %%
import glob

path = cwd+'/Data/SET'
print(path)
# Out:
# /home/poon/PycharmProjects/MyCourse/IPT/Data/SET

# %%
allFile = glob.glob(path +'/*.csv')
frame = pd.DataFrame()
list_ = []
print(allFile)
for file_ in allFile:
    df = pd.read_csv(file_, index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# ['/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1982-02-25.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1978-06-08.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_2003-10-09.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_2001-10-15.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1990-11-05.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1978-03-03.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_2005-08-24.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1994-09-15.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_2015-11-18.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1982-12-15.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_1986-10-29.csv', '/home/poon/PycharmProjects/MyCourse/IPT/Data/SET/set-history_EOD_2009-07-02.csv', '
# ...

# %%
frame
# Out:
#       <TICKER>  <DTYYYYMMDD>    <OPEN>    <HIGH>     <LOW>   <CLOSE>     <VOL>
# 0          SET      19820225  106.2400  106.2400  106.2400  106.2400    937600
# 0          SET      19780608  188.3300  188.3300  188.3300  188.3300   2205250
# 0          ACC      20031009   20.1000   20.1000   20.0000   20.0000   1188300
# 1       ADVANC      20031009   59.0000   59.5000   58.0000   58.5000   3836242
# 2          AEC      20031009   18.5000   18.7000   18.1000   18.5000   6469200
# 3       AEONTS      20031009   39.8000   40.0000   39.6000   39.8000    157500
# 4          AFC      20031009   13.6000   14.1000   13.6000   14.0000      5600
# 5           AH      20031009   25.2000   25.6000   25.0000   25.4000    143000
# 6          AHC      20031009   50.0000   54.0000   50.0000   54.0000      1100
# 7          AIT      20031009   22.8333   24.0000   22.5000   24.0000    567060
# 8           AJ      20031009    8.3000    8.3000    8.1500    8.1500    881200
# ...

# %%
frame.columns =  ['Symbol', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume']

# %%
frame.head()
# Out:
#    Symbol      Date    Open    High     Low   Close   Volume
# 0     SET  19820225  106.24  106.24  106.24  106.24   937600
# 0     SET  19780608  188.33  188.33  188.33  188.33  2205250
# 0     ACC  20031009   20.10   20.10   20.00   20.00  1188300
# 1  ADVANC  20031009   59.00   59.50   58.00   58.50  3836242
# 2     AEC  20031009   18.50   18.70   18.10   18.50  6469200

# %% [markdown]
# # getStock

# %%
stock = frame.loc[frame['Symbol']=='PTT']
stock.head()
# Out:
#     Symbol      Date   Open   High    Low  Close   Volume
# 147    PTT  20031009   83.5   84.5   82.5   83.5  5307173
# 169    PTT  20050824  244.0  250.0  242.0  248.0  4385950
# 392    PTT  20151118  270.0  272.0  263.0  263.0  9562300
# 234    PTT  20090702  235.0  236.0  225.0  229.0  6439816
# 371    PTT  20150212  355.0  359.0  352.0  359.0  6143100

# %%
stock = stock.sort_values(by='Date')
stock.head()
# Out:
#     Symbol      Date   Open   High   Low  Close     Volume
# 117    PTT  20011206  38.00  38.25  35.5  35.75  174919392
# 114    PTT  20011207  36.00  36.25  35.5  35.50   41253300
# 118    PTT  20011211  35.50  35.50  34.0  34.00   40915800
# 109    PTT  20011212  34.25  35.25  34.0  35.00   30729100
# 110    PTT  20011213  35.00  35.25  35.0  35.00   37596100

# %%
stock['Date'] = pd.to_datetime(stock['Date'],format='%Y%m%d')
stock = stock.set_index(['Date'])
stock.head()
# Out:
#            Symbol   Open   High   Low  Close     Volume
# Date
# 2001-12-06    PTT  38.00  38.25  35.5  35.75  174919392
# 2001-12-07    PTT  36.00  36.25  35.5  35.50   41253300
# 2001-12-11    PTT  35.50  35.50  34.0  34.00   40915800
# 2001-12-12    PTT  34.25  35.25  34.0  35.00   30729100
# 2001-12-13    PTT  35.00  35.25  35.0  35.00   37596100

# %%
del stock['Symbol']
stock.head()
# Out:
#              Open   High   Low  Close     Volume
# Date
# 2001-12-06  38.00  38.25  35.5  35.75  174919392
# 2001-12-07  36.00  36.25  35.5  35.50   41253300
# 2001-12-11  35.50  35.50  34.0  34.00   40915800
# 2001-12-12  34.25  35.25  34.0  35.00   30729100
# 2001-12-13  35.00  35.25  35.0  35.00   37596100

# %%
def getStock(name):
    stock = frame.loc[frame['Symbol']==name]
    stock = stock.sort_values(by='Date')
    stock['Date'] = pd.to_datetime(stock['Date'],format='%Y%m%d')
    stock = stock.set_index(['Date'])
    del stock['Symbol']
    return stock

# %%
getStock('ADVANC')
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 1991-11-05    4.5329    4.6259    4.2075    4.2540  280484640
# 1991-11-06    4.2540    4.3935    4.2075    4.3702   84359168
# 1991-11-07    4.4167    4.5329    4.3702    4.4864   87482312
# 1991-11-08    4.5097    4.7886    4.5097    4.6492   84496840
# 1991-11-11    4.6492    4.6957    4.5329    4.5794   42704400
# 1991-11-12    4.5794    4.5794    4.4400    4.4864   20222970
# 1991-11-13    4.4632    4.6027    4.3935    4.5794   26925230
# 1991-11-14    4.5097    4.6027    4.4864    4.5097   11589140
# 1991-11-15    4.4864    4.5794    4.4632    4.5794    9601710
# 1991-11-18    4.2772    4.4864    4.2307    4.4864   14617650
# 1991-11-19    4.4864    4.5562    4.4864    4.5562    7773420
# 1991-11-20    4.4864    4.5794    4.4864    4.5097    5390200
# 1991-11-21    4.4864    4.5097    4.4632    4.5097    4366360
# 1991-11-22    4.4632    4.4632    4.3935    4.4167    6254860
# ...

# %% [markdown]
# # Make it Function

# %%
import glob
import pandas as pd

def loadData(dataPath):
    path = dataPath
    allFile = glob.glob(path +'/*.csv')
    frame = pd.DataFrame()
    list_ = []
    #print(allFile)
    for file_ in allFile:
        df = pd.read_csv(file_, index_col=None, header=0)
        list_.append(df)
    frame = pd.concat(list_)   
    frame.columns =  ['Symbol', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume']
    return frame

def getStock(name,frame):
    stock = frame.loc[frame['Symbol']==name]
    stock = stock.sort_values(by='Date')
    stock['Date'] = pd.to_datetime(stock['Date'],format='%Y%m%d')
    stock = stock.set_index(['Date'])
    del stock['Symbol']
    return stock

# %%
import os 
cwd = os.getcwd()

dataPath = cwd +'/Data/SET'
allStocks = loadData(dataPath)

# %%
allStocks.head()
# Out:
#    Symbol      Date    Open    High     Low   Close   Volume
# 0     SET  19820225  106.24  106.24  106.24  106.24   937600
# 0     SET  19780608  188.33  188.33  188.33  188.33  2205250
# 0     ACC  20031009   20.10   20.10   20.00   20.00  1188300
# 1  ADVANC  20031009   59.00   59.50   58.00   58.50  3836242
# 2     AEC  20031009   18.50   18.70   18.10   18.50  6469200

# %%
SET = getStock('SET',allStocks)

# %%
SET.head()
# Out:
#               Open    High     Low   Close  Volume
# Date
# 1975-04-30  100.00  100.00  100.00  100.00  163310
# 1975-05-02   99.96   99.96   99.96   99.96  150220
# 1975-05-06   99.53   99.53   99.53   99.53  260100
# 1975-05-07   99.13   99.13   99.13   99.13   35480
# 1975-05-08   97.88   97.88   97.88   97.88   52500

# %% [markdown]
# # Export CSV

# %%
allStocks['Symbol'].unique()
# Out:
# array(['SET', 'ACC', 'ADVANC', ..., 'SAMARTH19', 'WHAM19', 'EGCOH19'],
#       dtype=object)

# %%
stocklist = allStocks['Symbol'].unique()

# %%
stocklist = stocklist[0:10]
stocklist

# %%
for i in range(len(stocklist)):
    stock = getStock(str(stocklist[i]), allStocks)
    stock.to_csv(cwd + '/Data/CSV/'+str(stocklist[i])+'.csv')

# %% [markdown]
# export Allstock

# %%
allStocks.to_csv(cwd + '/Data/egdata/'+'allStocks.csv')

# %% [markdown]
# # Read CSV

# %%
read_path = cwd +'/Data/CSV/'
ADVANC = pd.read_csv(read_path+'ADVANC.csv')

# %%
ADVANC.head()
# Out:
#          Date    Open    High     Low   Close     Volume
# 0  1991-11-05  4.5329  4.6259  4.2075  4.2540  280484640
# 1  1991-11-06  4.2540  4.3935  4.2075  4.3702   84359168
# 2  1991-11-07  4.4167  4.5329  4.3702  4.4864   87482312
# 3  1991-11-08  4.5097  4.7886  4.5097  4.6492   84496840
# 4  1991-11-11  4.6492  4.6957  4.5329  4.5794   42704400
